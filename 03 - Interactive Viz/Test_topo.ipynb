# %%
import folium
import json
import pandas as pd
import random

# %%
cantons_geo = r'data/ch-cantons.topojson.json'

swiss_map = folium.Map(location=[46.801111,8.226667], zoom_start=7.7)
swiss_map.choropleth(geo_path=cantons_geo, 
                     topojson='objects.cantons', 
                     line_opacity=0.1, 
                     fill_opacity=0.3,
                     fill_color='YlGnBu'
                    )
swiss_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
with open(cantons_geo, "r") as fin:
    cantons = json.load(fin)

# %%
idx = 11
print(cantons['objects']['cantons']['geometries'][idx]['id'])
print(cantons['objects']['cantons']['geometries'][idx]['properties']['name'])
# Out:
# BS
# Basel-Stadt

# %%
list_ids = []
val = []
for i in range(len(cantons['objects']['cantons']['geometries'])):
    list_ids.append(cantons['objects']['cantons']['geometries'][i]['id'])
    val.append(random.random())
    
frame = {'Cantons': list_ids, 'values':val}

# %%
df = pd.DataFrame.from_dict(frame)
df.head()
# Out:
#   Cantons    values
# 0      ZH  0.031328
# 1      BE  0.226538
# 2      LU  0.066659
# 3      UR  0.548977
# 4      SZ  0.721259

# %%
swiss_map = folium.Map(location=[46.801111,8.226667], zoom_start=7.7)
swiss_map.choropleth(geo_path=cantons_geo, 
                     data=df,
                     columns=['Cantons', 'values'],
                     key_on='objects.id',
                     #topojson='objects.cantons',
                     #line_opacity=0.1, 
                     #fill_opacity=0.3,
                     fill_color='YlGn',
                     legend_name = 'Random numbers'
                    )
swiss_map
# Out:
# C:\Users\glede\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: FutureWarning: 'threshold_scale' default behavior has changed. Now you get a linear scale between the 'min' and the 'max' of your data. To get former behavior, use folium.utilities.split_six.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\glede\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\map.py in _repr_html_(self, **kwargs)
#     177             self._parent = None
#     178         else:
# --> 179             out = self._parent._repr_html_(**kwargs)
#     180         return out
#     181
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\element.py in _repr_html_(self, **kwargs)
#     367
#     368         """
# --> 369         html = self.render(**kwargs)
#     370         html = "data:text/html;base64," + base64.b64encode(html.encode('utf8')).decode('utf8')  # noqa
#     371
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\element.py in render(self, **kwargs)
#     357         """Renders the HTML representation of the element."""
#     358         for name, child in self._children.items():
# --> 359             child.render(**kwargs)
#     360         return self._template.render(this=self, kwargs=kwargs)
#     361
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\element.py in render(self, **kwargs)
#     665
#     666         for name, element in self._children.items():
# --> 667             element.render(**kwargs)
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\element.py in render(self, **kwargs)
#     661         script = self._template.module.__dict__.get('script', None)
#     662         if script is not None:
# --> 663             figure.script.add_children(Element(script(self, kwargs)),
#     664                                        name=self.get_name())
#     665
#
# C:\Users\glede\Anaconda3\lib\site-packages\jinja2\runtime.py in __call__(self, *args, **kwargs)
#     434             raise TypeError('macro %r takes not more than %d argument(s)' %
#     435                             (self.name, len(self.arguments)))
# --> 436         return self._func(*arguments)
#     437
#     438     def __repr__(self):
#
# <template> in macro(l_this, l_kwargs)
#
# C:\Users\glede\Anaconda3\lib\site-packages\jinja2\runtime.py in call(_Context__self, _Context__obj, *args, **kwargs)
#     194                 args = (__self.environment,) + args
#     195         try:
# --> 196             return __obj(*args, **kwargs)
#     197         except StopIteration:
#     198             return __self.environment.undefined('value was undefined because '
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\features.py in style_data(self)
#     352
#     353         for feature in self.data['features']:
# --> 354             feature.setdefault('properties', {}).setdefault('style', {}).update(self.style_function(feature))  # noqa
#     355         return json.dumps(self.data, sort_keys=True)
#     356
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\folium.py in style_function(x)
#     671                 "color": line_color,
#     672                 "fillOpacity": fill_opacity,
# --> 673                 "fillColor": color_scale_fun(x)
#     674             }
#     675
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\folium.py in color_scale_fun(x)
#     659             def color_scale_fun(x):
#     660                 return color_range[len(
# --> 661                     [u for u in color_domain if
#     662                      u <= color_data[get_by_key(x, key_on)]])]
#     663         else:
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\folium.py in <listcomp>(.0)
#     660                 return color_range[len(
#     661                     [u for u in color_domain if
# --> 662                      u <= color_data[get_by_key(x, key_on)]])]
#     663         else:
#     664             def color_scale_fun(x):
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\folium.py in get_by_key(obj, key)
#     655                 return (obj.get(key, None) if len(key.split('.')) <= 1 else
#     656                         get_by_key(obj.get(key.split('.')[0], None),
# --> 657                                    '.'.join(key.split('.')[1:])))
#     658
#     659             def color_scale_fun(x):
#
# C:\Users\glede\Anaconda3\lib\site-packages\folium\folium.py in get_by_key(obj, key)
#     653
#     654             def get_by_key(obj, key):
# --> 655                 return (obj.get(key, None) if len(key.split('.')) <= 1 else
#     656                         get_by_key(obj.get(key.split('.')[0], None),
#     657                                    '.'.join(key.split('.')[1:])))
#
# AttributeError: 'NoneType' object has no attribute 'get'
